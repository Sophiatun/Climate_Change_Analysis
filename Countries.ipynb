# %%
# Import the necessary libraries
import pandas as pd
import json
import requests
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %%
# Read the CSV file
pd.options.display.max_colwidth = 200
country_df = pd.read_csv("Data/GlobalLandTemperaturesByCountry.csv")
country_df
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1743-11-01               4.384                          2.294
# 1       1743-12-01                 NaN                            NaN
# 2       1744-01-01                 NaN                            NaN
# 3       1744-02-01                 NaN                            NaN
# 4       1744-03-01                 NaN                            NaN
# ...            ...                 ...                            ...
# 577457  2013-05-01              19.059                          1.022
# 577458  2013-06-01              17.613                          0.473
# 577459  2013-07-01              17.000                          0.453
# 577460  2013-08-01              19.759                          0.717
# 577461  2013-09-01                 NaN                            NaN
#
#          Country
# 0          Åland
# 1          Åland
# 2          Åland
# 3          Åland
# 4          Åland
# ...          ...
# 577457  Zimbabwe
# 577458  Zimbabwe
# 577459  Zimbabwe
# 577460  Zimbabwe
# 577461  Zimbabwe
#
# [577462 rows x 4 columns]

# %%
# Using 'to_list()' converts the column labels to a Python list
columns = country_df.columns.to_list()
columns
# Out:
# ['dt', 'AverageTemperature', 'AverageTemperatureUncertainty', 'Country']

# %%
# Checck data types
country_df.dtypes
# Out:
# dt                                object
# AverageTemperature               float64
# AverageTemperatureUncertainty    float64
# Country                           object
# dtype: object

# %%
# Convert to date time format
country_df["dt"] = pd.to_datetime(country_df["dt"])

# %%
# Check the data types again
country_df.dtypes
# Out:
# dt                               datetime64[ns]
# AverageTemperature                      float64
# AverageTemperatureUncertainty           float64
# Country                                  object
# dtype: object

# %%
# Determine the number of unique countries in the dataset
country_df["Country"].unique()
len(country_df["Country"].unique())
# Out:
# 243

# %%
countries_grouped = country_df.groupby("Country")
countries_grouped.head()
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1743-11-01               4.384                          2.294
# 1       1743-12-01                 NaN                            NaN
# 2       1744-01-01                 NaN                            NaN
# 3       1744-02-01                 NaN                            NaN
# 4       1744-03-01                 NaN                            NaN
# ...            ...                 ...                            ...
# 575497  1850-01-01              22.187                          1.618
# 575498  1850-02-01              23.538                          1.635
# 575499  1850-03-01              22.528                          2.195
# 575500  1850-04-01              20.000                          1.817
# 575501  1850-05-01              17.067                          1.548
#
#          Country
# 0          Åland
# 1          Åland
# 2          Åland
# 3          Åland
# 4          Åland
# ...          ...
# 575497  Zimbabwe
# 575498  Zimbabwe
# 575499  Zimbabwe
# 575500  Zimbabwe
# 575501  Zimbabwe
#
# [1215 rows x 4 columns]

# %%
# Find the earliest date all countries have in common

earliest_date = countries_grouped["dt"].min().max()
earliest_date
# Out:
# '1950-02-01'

# %%
# Find the latest date all countries have in common

latest_date = countries_grouped["dt"].max().min()
latest_date
# Out:
# '2013-09-01'

# %%
date_range = (f"Our date range is {earliest_date} to {latest_date}")
print(date_range)
# Out:
# Our date range is 1950-02-01 to 2013-09-01

# %%
cleaned_countries = country_df[country_df['dt']>=earliest_date]
cleaned_countries.head()
# Out:
#               dt  AverageTemperature  AverageTemperatureUncertainty Country
# 2475  1950-02-01              -1.804                          0.305   Åland
# 2476  1950-03-01               0.090                          0.439   Åland
# 2477  1950-04-01               3.630                          0.342   Åland
# 2478  1950-05-01               8.106                          0.239   Åland
# 2479  1950-06-01              12.783                          0.235   Åland

# %%
cleaned_countries_grouped = cleaned_countries.groupby(country_df["Country"])
cleaned_countries_grouped.head()
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 2475    1950-02-01              -1.804                          0.305
# 2476    1950-03-01               0.090                          0.439
# 2477    1950-04-01               3.630                          0.342
# 2478    1950-05-01               8.106                          0.239
# 2479    1950-06-01              12.783                          0.235
# ...            ...                 ...                            ...
# 576698  1950-02-01              24.089                          0.296
# 576699  1950-03-01              23.642                          0.444
# 576700  1950-04-01              22.258                          0.369
# 576701  1950-05-01              17.536                          0.264
# 576702  1950-06-01              16.198                          0.281
#
#          Country
# 2475       Åland
# 2476       Åland
# 2477       Åland
# 2478       Åland
# 2479       Åland
# ...          ...
# 576698  Zimbabwe
# 576699  Zimbabwe
# 576700  Zimbabwe
# 576701  Zimbabwe
# 576702  Zimbabwe
#
# [1215 rows x 4 columns]

# %%
cleaned_countries_grouped_dropna = cleaned_countries.dropna()
cleaned_countries_grouped_dropna
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 2475    1950-02-01              -1.804                          0.305
# 2476    1950-03-01               0.090                          0.439
# 2477    1950-04-01               3.630                          0.342
# 2478    1950-05-01               8.106                          0.239
# 2479    1950-06-01              12.783                          0.235
# ...            ...                 ...                            ...
# 577456  2013-04-01              21.142                          0.495
# 577457  2013-05-01              19.059                          1.022
# 577458  2013-06-01              17.613                          0.473
# 577459  2013-07-01              17.000                          0.453
# 577460  2013-08-01              19.759                          0.717
#
#          Country
# 2475       Åland
# 2476       Åland
# 2477       Åland
# 2478       Åland
# 2479       Åland
# ...          ...
# 577456  Zimbabwe
# 577457  Zimbabwe
# 577458  Zimbabwe
# 577459  Zimbabwe
# 577460  Zimbabwe
#
# [184667 rows x 4 columns]

# %%
final_df = cleaned_countries_grouped_dropna.groupby(country_df["Country"])
final_df.head()
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 2475    1950-02-01              -1.804                          0.305
# 2476    1950-03-01               0.090                          0.439
# 2477    1950-04-01               3.630                          0.342
# 2478    1950-05-01               8.106                          0.239
# 2479    1950-06-01              12.783                          0.235
# ...            ...                 ...                            ...
# 576698  1950-02-01              24.089                          0.296
# 576699  1950-03-01              23.642                          0.444
# 576700  1950-04-01              22.258                          0.369
# 576701  1950-05-01              17.536                          0.264
# 576702  1950-06-01              16.198                          0.281
#
#          Country
# 2475       Åland
# 2476       Åland
# 2477       Åland
# 2478       Åland
# 2479       Åland
# ...          ...
# 576698  Zimbabwe
# 576699  Zimbabwe
# 576700  Zimbabwe
# 576701  Zimbabwe
# 576702  Zimbabwe
#
# [1210 rows x 4 columns]

# %%
final_df.to_csv("Countries.csv")

# %%
pd.options.display.max_colwidth = 200
# Extract the ZIP file manually as pd.read_csv function did not work due to compatibility issue
import zipfile
with zipfile.ZipFile("Data/GlobalLandTemperaturesByCity.csv.zip", 'r') as zip_ref:
    zip_ref.extractall("Data/")

# Read the CSV file directly
city_df = pd.read_csv("Data/GlobalLandTemperaturesByCity.csv")

city_df
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0        1743-11-01               6.068                          1.737
# 1        1743-12-01                 NaN                            NaN
# 2        1744-01-01                 NaN                            NaN
# 3        1744-02-01                 NaN                            NaN
# 4        1744-03-01                 NaN                            NaN
# ...             ...                 ...                            ...
# 8599207  2013-05-01              11.464                          0.236
# 8599208  2013-06-01              15.043                          0.261
# 8599209  2013-07-01              18.775                          0.193
# 8599210  2013-08-01              18.025                          0.298
# 8599211  2013-09-01                 NaN                            NaN
#
#            City      Country Latitude Longitude
# 0         Århus      Denmark   57.05N    10.33E
# 1         Århus      Denmark   57.05N    10.33E
# 2         Århus      Denmark   57.05N    10.33E
# 3         Århus      Denmark   57.05N    10.33E
# 4         Århus      Denmark   57.05N    10.33E
# ...         ...          ...      ...       ...
# 8599207  Zwolle  Netherlands   52.24N     5.26E
# 8599208  Zwolle  Netherlands   52.24N     5.26E
# 8599209  Zwolle  Netherlands   52.24N     5.26E
# 8599210  Zwolle  Netherlands   52.24N     5.26E
# 8599211  Zwolle  Netherlands   52.24N     5.26E
#
# [8599212 rows x 7 columns]

# %%
# Converts the column labels to a Python list
city_columns = list(city_df)
city_columns
# Out:
# ['dt',
#  'AverageTemperature',
#  'AverageTemperatureUncertainty',
#  'City',
#  'Country',
#  'Latitude',
#  'Longitude']

# %%
# Checck data types
city_df.dtypes
# Out:
# dt                                object
# AverageTemperature               float64
# AverageTemperatureUncertainty    float64
# City                              object
# Country                           object
# Latitude                          object
# Longitude                         object
# dtype: object

# %%
# Convert to date time format
city_df["dt"] = pd.to_datetime(city_df["dt"])

# %%
# Check the data types again
city_df.dtypes
# Out:
# dt                               datetime64[ns]
# AverageTemperature                      float64
# AverageTemperatureUncertainty           float64
# City                                     object
# Country                                  object
# Latitude                                 object
# Longitude                                object
# dtype: object

# %%
# Determine the number of unique countries in the dataset
city_df["Country"].unique()
len(city_df["Country"].unique())
# Out:
# 159

# %%
# Determine the number of unique cities in the dataset
city_df["City"].unique()
len(city_df["City"].unique())
# Out:
# 3448

# %%
# Group by 'Year', 'City', and 'Country' and calculate the mean temperature for each year
yearly_avg_city_df = city_df.groupby(['dt', 'City', 'Country'])['AverageTemperature'].mean().reset_index()

# Rename the columns
yearly_avg_city_df = yearly_avg_city_df.rename(columns={'dt': 'Year', 'AverageTemperature': 'Yearly Average Temperature'})

# Display the DataFrame with the average temperature for each year
(yearly_avg_city_df)
# Out:
#               Year             City         Country  \
# 0       1743-11-01         A Coruña           Spain
# 1       1743-11-01           Aachen         Germany
# 2       1743-11-01          Aalborg         Denmark
# 3       1743-11-01         Aberdeen  United Kingdom
# 4       1743-11-01  Aix En Provence          France
# ...            ...              ...             ...
# 8553173 2013-09-01            Århus         Denmark
# 8553174 2013-09-01            Çorlu          Turkey
# 8553175 2013-09-01            Çorum          Turkey
# 8553176 2013-09-01          Öskemen      Kazakhstan
# 8553177 2013-09-01           Ürümqi           China
#
#          Yearly Average Temperature
# 0                            10.779
# 1                             6.425
# 2                             6.068
# 3                             8.758
# 4                             7.478
# ...                             ...
# 8553173                         NaN
# 8553174                         NaN
# 8553175                         NaN
# 8553176                         NaN
# 8553177                         NaN
#
# [8553178 rows x 4 columns]

# %%
cleaned_cities = yearly_avg_city_df[yearly_avg_city_df['Year']>="1950-02-01"]
cleaned_cities
# Out:
#               Year      City     Country  Yearly Average Temperature
# 5886818 1950-02-01  A Coruña       Spain                      10.035
# 5886819 1950-02-01    Aachen     Germany                       4.661
# 5886820 1950-02-01   Aalborg     Denmark                       1.423
# 5886821 1950-02-01       Aba     Nigeria                      27.105
# 5886822 1950-02-01    Abadan        Iran                      11.975
# ...            ...       ...         ...                         ...
# 8553173 2013-09-01     Århus     Denmark                         NaN
# 8553174 2013-09-01     Çorlu      Turkey                         NaN
# 8553175 2013-09-01     Çorum      Turkey                         NaN
# 8553176 2013-09-01   Öskemen  Kazakhstan                         NaN
# 8553177 2013-09-01    Ürümqi       China                         NaN
#
# [2666360 rows x 4 columns]

# %%
final_city_df = cleaned_cities.dropna()
final_city_df
# Out:
#               Year       City        Country  Yearly Average Temperature
# 5886818 1950-02-01   A Coruña          Spain                      10.035
# 5886819 1950-02-01     Aachen        Germany                       4.661
# 5886820 1950-02-01    Aalborg        Denmark                       1.423
# 5886821 1950-02-01        Aba        Nigeria                      27.105
# 5886822 1950-02-01     Abadan           Iran                      11.975
# ...            ...        ...            ...                         ...
# 8553051 2013-09-01       Xico         Mexico                      18.313
# 8553105 2013-09-01    Yonkers  United States                      17.408
# 8553120 2013-09-01  Zacatecas         Mexico                      18.830
# 8553125 2013-09-01     Zamora         Mexico                      21.155
# 8553130 2013-09-01    Zapopan         Mexico                      23.646
#
# [2663301 rows x 4 columns]

# %%
# final_city_df = cleaned_cities_dropna.groupby(['City', 'Country']).reset_index()
final_city_df.to_csv("Cleaned Data/Cities.csv", index=False)
